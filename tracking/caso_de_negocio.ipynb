# %%
import os
import json
import pandas as pd

# %%
def read_json(path: str, file_name: str):
    """This method is used to read the json file
    Args:
        path (str): path of the file
        file_name (str): name of the file
    Returns:
        df_tickets (pd.DataFrame): dataframe with the tickets"""
    file_path = os.path.join(path, file_name)
    with open(file_path, "r") as file:
        datos = json.load(file)
    df_tickets = pd.json_normalize(datos)
    return df_tickets

# %%
df_tickets = read_json(path = "data/data_raw", 
                       file_name = "tickets_classification_eng.json")

# %%
df_tickets.sample(4)
# Out:
#                     _index      _type      _id  _score _source.tags  \
# 11357  complaint-public-v2  complaint  3669714     0.0         None
# 72213  complaint-public-v2  complaint  1784703     0.0         None
# 43362  complaint-public-v2  complaint  2496239     0.0         None
# 18172  complaint-public-v2  complaint  2571525     0.0         None
#
#       _source.zip_code _source.complaint_id  \
# 11357             None              3669714
# 72213            191XX              1784703
# 43362            53704              2496239
# 18172            10017              2571525
#
#                                          _source.issue  \
# 11357                  Written notification about debt
# 72213                                 Billing disputes
# 43362  Problem with a purchase shown on your statement
# 18172             Incorrect information on your report
#
#            _source.date_received _source.state  ... _source.company_response  \
# ...

# %%
df_tickets.shape
# Out:
# (78313, 22)

# %%
df_tickets[["_source.complaint_what_happened",
            "_source.product",
            "_source.sub_product"]]
# Out:
#                          _source.complaint_what_happened  \
# 0
# 1      Good morning my name is XXXX XXXX and I apprec...
# 2      I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  On Wednesday, XX/XX/XXXX I called Chas, my XXX...
# 78310  I am not familiar with XXXX pay and did not un...
# 78311  I have had flawless credit for 30 yrs. I've ha...
# 78312  Roughly 10+ years ago I closed out my accounts...
#
#                    _source.product                         _source.sub_product
# 0                  Debt collection                            Credit card debt
# 1                  Debt collection                            Credit card debt
# 2      Credit card or prepaid card  General-purpose credit card or charge card
# 3                         Mortgage                  Conventional home mortgage
# 4      Credit card or prepaid card  General-purpose credit card or charge card
# ...
